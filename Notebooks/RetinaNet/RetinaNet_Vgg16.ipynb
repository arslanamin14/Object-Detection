# %% [markdown]
# **Mount the drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Unzip the data**

# %%
zip_path = '/content/gdrive/My Drive/Dataset.zip'
# !unzip '$zip_path' 
# !unzip -q '/content/SIMS dataset/images.zip' 
# !unzip -q '/content/SIMS dataset/Annotations_in_3_formats.zip'
# Out:
# Archive:  /content/gdrive/My Drive/Dataset.zip
#   inflating: SIMS dataset/test.txt
#   inflating: SIMS dataset/validation.txt
#   inflating: SIMS dataset/training.txt
#   inflating: SIMS dataset/Assignment-2_modified scope.pdf
#   inflating: SIMS dataset/Annotations_in_3_formats.zip
#   inflating: SIMS dataset/images.zip

# %% [markdown]
# **Copy the Pascal_Voc Annotations to the images folder**

# %%
# %cp -R "/content/annotations/pascal_voc/Annotations/."  "/content/images"

# %% [markdown]
# **Make the directories**

# %%
# !mkdir Dataset
# !mkdir Dataset/train
# !mkdir Dataset/train/images
# !mkdir Dataset/train/annotations
# !mkdir Dataset/valid
# !mkdir Dataset/valid/images
# !mkdir Dataset/valid/annotations
# !mkdir Dataset/test
# !mkdir Dataset/test/images
# !mkdir Dataset/test/annotations

# %% [markdown]
# **Creating CSV files and placing images and labels in the directories**

# %%
import shutil
import os
#copy files based on {datasets in txt}

def copy(filepath,dest_dir):
    with open(filepath) as fp:
        for line in fp:
            os.makedirs(dest_dir, exist_ok=True)  # succeeds even if directory exists.
            shutil.copy(line.replace('\n', ''), dest_dir+"/images") #image
            shutil.copy(line.replace('.jpg\n', '.xml'), dest_dir+"/annotations") ##label

#copy files based on {datasets in txt}
copy('/content/SIMS dataset/training.txt','Dataset/train/')
copy('/content/SIMS dataset/validation.txt','Dataset/valid/')
copy('/content/SIMS dataset/test.txt','Dataset/test/')

#from preprocessing.pascal_voc_to_csv import xml_to_csv

import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET

def xml_to_csv(path,image_path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        #print(xml_file)
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            bbx = member.find('bndbox')
            xmin = int(bbx.find('xmin').text)
            ymin = int(bbx.find('ymin').text)
            xmax = int(bbx.find('xmax').text)
            ymax = int(bbx.find('ymax').text)
            label = member.find('name').text
            
            size = root.find('size') #contains height and width of image
            w = int(size.find('width').text)
            h = int(size.find('height').text)
            
            # truncate any bb coordinates that fall outside of the image
            xmin = max(0, xmin)
            ymin = max(0, ymin)
            xmax = min(w, xmax)
            ymax = min(h, ymax)
            
            # # ignore the bounding boxes where the minimum values are larger
            # # than the maximum values and vice-versa due to annotation errors
            if xmin >= xmax or ymin >= ymax:
                continue
            elif xmax <= xmin or ymax <= ymin:
                continue
            
            file_path = image_path+root.find('filename').text+".jpg"
            value = (file_path,
                     xmin,
                     ymin,
                     xmax,
                     ymax,
                     label,
                     )
            xml_list.append(value)
    column_name = ['filename','xmin', 'ymin', 'xmax', 'ymax','class']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


def main():
    root_path = "Dataset/"
    datasets = ['train','test','valid']
    for ds in datasets:
        #image_path = os.path.join(os.getcwd(), root_path+ds, 'annotations')
        image_path = os.path.join(root_path+ds, 'annotations/')
        print(image_path)
        update_path = os.path.join(root_path+ds, 'images/')
        xml_df = xml_to_csv(image_path,update_path)
        xml_df.to_csv('labels_{}.csv'.format(ds), index=None, header=False)
        print('Successfully converted xml to csv.')

# %% [markdown]
# **Clone the Repository**

# %%
# !git clone https://github.com/fizyr/keras-retinanet
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 5711 (delta 0), reused 1 (delta 0), pack-reused 5705
# Receiving objects: 100% (5711/5711), 13.37 MiB | 29.95 MiB/s, done.
# Resolving deltas: 100% (3831/3831), done.

# %% [markdown]
# **Run the command for installing the packages**

# %%
# !pip install ./keras-retinanet/
# Out:
# Processing ./keras-retinanet
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (2.3.1)
# Collecting keras-resnet==0.1.0
#   Downloading https://files.pythonhosted.org/packages/05/46/ad0b2d1a05d9497bd80c98a2c3f4d8be38a4601ace69af72814f5fafd851/keras-resnet-0.1.0.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (1.4.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (0.29.17)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (7.0.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (4.1.2.30)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from keras-retinanet==0.5.1) (3.38.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-retinanet==0.5.1) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-retinanet==0.5.1) (1.18.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-retinanet==0.5.1) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-retinanet==0.5.1) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-retinanet==0.5.1) (2.10.0)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->keras-retinanet==0.5.1) (2.4.0)
# Building wheels for collected packages: keras-retinanet, keras-resnet
#   Building wheel for keras-retinanet (setup.py) ... done
#   Created wheel for keras-retinanet: filename=keras_retinanet-0.5.1-cp36-cp36m-linux_x86_64.whl size=170130 sha256=b931bc73616e6f6148852e277be2d2e31655d0505ce71172d868755e053bc680
#   Stored in directory: /root/.cache/pip/wheels/b2/9f/57/cb0305f6f5a41fc3c11ad67b8cedfbe9127775b563337827ba
#   Building wheel for keras-resnet (setup.py) ... done
#   Created wheel for keras-resnet: filename=keras_resnet-0.1.0-py2.py3-none-any.whl size=13346 sha256=6e3856eabca93ad0e844096ab4ea9993f8a902daf303e3c6f089c36cd555fe6a
#   Stored in directory: /root/.cache/pip/wheels/80/dd/ac/842235b63dddac12faa4b48ebe58b8944e8c2e57c2e38dddb6
# Successfully built keras-retinanet keras-resnet
# Installing collected packages: keras-resnet, keras-retinanet
# Successfully installed keras-resnet-0.1.0 keras-retinanet-0.5.1

# %% [markdown]
# **Run the Command**

# %%
# !python /content/keras-retinanet/setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning keras_retinanet/utils/compute_overlap.pyx to keras_retinanet/utils/compute_overlap.c
# creating keras_retinanet
# creating keras_retinanet/utils
# error: /content/keras_retinanet/utils/compute_overlap.pyx

# %% [markdown]
# **Move the Dataset in the RetinaNet Folder**

# %%
# !mv "/content/Dataset"  "/content/keras-retinanet"

# %% [markdown]
# **Move the labels files in the RetinaNet Folder**

# %%
# %cp -R "/content/gdrive/My Drive/ACV2dataunzip/labels/classes.csv"  "/content/keras-retinanet"
# %cp -R "/content/gdrive/My Drive/ACV2dataunzip/labels/labels_test.csv"  "/content/keras-retinanet"
# %cp -R "/content/gdrive/My Drive/ACV2dataunzip/labels/labels_train.csv"  "/content/keras-retinanet"
# %cp -R "/content/gdrive/My Drive/ACV2dataunzip/labels/labels_valid.csv"  "/content/keras-retinanet"

# %% [markdown]
# **Train the Model**

# %%
# !cd "/content/keras-retinanet/keras_retinanet/bin" && retinanet-train  --freeze-backbone --backbone vgg16 --no-resize --compute-val-loss --random-transform --batch-size 16 --steps 100 --epochs 70 --multiprocessing --compute-val-loss  --weighted-average --snapshot-path "/content/gdrive/My Drive/ACV2/retinaa"  csv /content/keras-retinanet/labels_train.csv /content/keras-retinanet/classes.csv
# Out:
# Using TensorFlow backend.
# 2020-05-15 08:36:46.173126: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/keras_retinanet/bin/train.py:378: UserWarning: Using experimental backbone vgg16. Only resnet50 has been properly tested.
#   warnings.warn('Using experimental backbone {}. Only resnet50 has been properly tested.'.format(parsed_args.backbone))
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Creating model, this may take a second...
# 2020-05-15 08:36:49.382655: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-15 08:36:49.408025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.409047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-15 08:36:49.409094: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-15 08:36:49.429534: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-15 08:36:49.436968: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-15 08:36:49.445253: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-15 08:36:49.458794: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-15 08:36:49.472962: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-15 08:36:49.498923: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-15 08:36:49.499157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.500346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.501337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-05-15 08:36:49.509604: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-05-15 08:36:49.509875: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x321abc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-05-15 08:36:49.509914: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-05-15 08:36:49.612255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.613448: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x321ad80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-05-15 08:36:49.613502: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-05-15 08:36:49.613846: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.614686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-15 08:36:49.614745: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-15 08:36:49.614817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-15 08:36:49.614857: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-05-15 08:36:49.614895: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-05-15 08:36:49.614930: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-05-15 08:36:49.615000: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-05-15 08:36:49.615038: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-15 08:36:49.615172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.616103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:49.616972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0
# 2020-05-15 08:36:49.617029: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-15 08:36:50.192640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-05-15 08:36:50.192704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0
# 2020-05-15 08:36:50.192724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N
# 2020-05-15 08:36:50.193112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:50.194121: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:36:50.195065: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-05-15 08:36:50.195129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14974 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[
0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, None, None, 1 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, None, None, 2 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, None, None, 2 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, None, None, 2 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, None, None, 2 0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, None, None, 5 1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, None, None, 5 2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, None, None, 5 2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, None, None, 5 0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, None, None, 5 2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, None, None, 5 2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, None, None, 5 2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, None, None, 5 0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# C5_reduced (Conv2D)             (None, None, None, 2 131328      block5_pool[0][0]
# __________________________________________________________________________________________________
# P5_upsampled (UpsampleLike)     (None, None, None, 2 0           C5_reduced[0][0]
#                                                                  block4_pool[0][0]
# __________________________________________________________________________________________________
# C4_reduced (Conv2D)             (None, None, None, 2 131328      block4_pool[0][0]
# __________________________________________________________________________________________________
# P4_merged (Add)                 (None, None, None, 2 0           P5_upsampled[0][0]
#                                                                  C4_reduced[0][0]
# __________________________________________________________________________________________________
# P4_upsampled (UpsampleLike)     (None, None, None, 2 0           P4_merged[0][0]
#                                                                  block3_pool[0][0]
# __________________________________________________________________________________________________
# C3_reduced (Conv2D)             (None, None, None, 2 65792       block3_pool[0][0]
# __________________________________________________________________________________________________
# P6 (Conv2D)                     (None, None, None, 2 1179904     block5_pool[0][0]
# __________________________________________________________________________________________________
# P3_merged (Add)                 (None, None, None, 2 0           P4_upsampled[0][0]
#                                                                  C3_reduced[0][0]
# __________________________________________________________________________________________________
# C6_relu (Activation)            (None, None, None, 2 0           P6[0][0]
# __________________________________________________________________________________________________
# P3 (Conv2D)                     (None, None, None, 2 590080      P3_merged[0][0]
# __________________________________________________________________________________________________
# P4 (Conv2D)                     (None, None, None, 2 590080      P4_merged[0][0]
# __________________________________________________________________________________________________
# P5 (Conv2D)                     (None, None, None, 2 590080      C5_reduced[0][0]
# __________________________________________________________________________________________________
# P7 (Conv2D)                     (None, None, None, 2 590080      C6_relu[0][0]
# __________________________________________________________________________________________________
# regression_submodel (Model)     (None, None, 4)      2443300     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# classification_submodel (Model) (None, None, 15)     2671495     P3[0][0]
#                                                                  P4[0][0]
#                                                                  P5[0][0]
#                                                                  P6[0][0]
#                                                                  P7[0][0]
# __________________________________________________________________________________________________
# regression (Concatenate)        (None, None, 4)      0           regression_submodel[1][0]
#                                                                  regression_submodel[2][0]
#                                                                  regression_submodel[3][0]
#                                                                  regression_submodel[4][0]
#                                                                  regression_submodel[5][0]
# __________________________________________________________________________________________________
# classification (Concatenate)    (None, None, 15)     0           classification_submodel[1][0]
#                                                                  classification_submodel[2][0]
#                                                                  classification_submodel[3][0]
#                                                                  classification_submodel[4][0]
#                                                                  classification_submodel[5][0]
# ==================================================================================================
# Total params: 23,698,155
# Trainable params: 8,983,467
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________
# None
# Epoch 1/70
# 2020-05-15 08:37:02.916498: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-15 08:37:05.186566: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 100/100 [==============================] - 463s 5s/step - loss: 26.1027 - regression_loss: 4.3174 - classification_loss: 21.7853
#
# Epoch 00001: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_01.h5
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `mAP` which is not available. Available metrics are: loss,regression_loss,classification_loss,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# Epoch 2/70
#  22/100 [=====>........................] - ETA: 5:51 - loss: 3.8343 - regression_loss: 2.7666 - classification_loss: 1.06772020-05-15 08:46:22.733136: W tensorflow/core/common_runtime/bfc_allocator.cc:245] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2020-05-15 08:46:22.734784: W tensorflow/core/kernels/gpu_utils.cc:49] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 100/100 [==============================] - 486s 5s/step - loss: 3.5730 - regression_loss: 2.6562 - classification_loss: 0.9168
#
# Epoch 00002: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_02.h5
# Epoch 3/70
# 100/100 [==============================] - 358s 4s/step - loss: 3.0916 - regression_loss: 2.3422 - classification_loss: 0.7494
#
# Epoch 00003: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_03.h5
# Epoch 4/70
# 100/100 [==============================] - 348s 3s/step - loss: 2.8952 - regression_loss: 2.1753 - classification_loss: 0.7199
#
# Epoch 00004: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_04.h5
# Epoch 5/70
# 100/100 [==============================] - 359s 4s/step - loss: 2.7409 - regression_loss: 2.0555 - classification_loss: 0.6854
#
# Epoch 00005: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_05.h5
# Epoch 6/70
# 100/100 [==============================] - 353s 4s/step - loss: 2.6317 - regression_loss: 1.9721 - classification_loss: 0.6596
#
# Epoch 00006: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_06.h5
# Epoch 7/70
# 100/100 [==============================] - 360s 4s/step - loss: 2.5605 - regression_loss: 1.9141 - classification_loss: 0.6464
#
# Epoch 00007: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_07.h5
# Epoch 8/70
# 100/100 [==============================] - 354s 4s/step - loss: 2.4902 - regression_loss: 1.8611 - classification_loss: 0.6291
#
# Epoch 00008: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_08.h5
# Epoch 9/70
# 100/100 [==============================] - 362s 4s/step - loss: 2.4462 - regression_loss: 1.8301 - classification_loss: 0.6161
#
# Epoch 00009: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_09.h5
# Epoch 10/70
# 100/100 [==============================] - 353s 4s/step - loss: 2.3748 - regression_loss: 1.7734 - classification_loss: 0.6014
#
# Epoch 00010: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_10.h5
# Epoch 11/70
# 100/100 [==============================] - 356s 4s/step - loss: 2.3391 - regression_loss: 1.7487 - classification_loss: 0.5904
#
# Epoch 00011: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_11.h5
# Epoch 12/70
# 100/100 [==============================] - 347s 3s/step - loss: 2.2815 - regression_loss: 1.7060 - classification_loss: 0.5755
#
# Epoch 00012: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_12.h5
# Epoch 13/70
# 100/100 [==============================] - 358s 4s/step - loss: 2.2673 - regression_loss: 1.6897 - classification_loss: 0.5776
#
# Epoch 00013: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_13.h5
# Epoch 14/70
# 100/100 [==============================] - 352s 4s/step - loss: 2.2149 - regression_loss: 1.6555 - classification_loss: 0.5594
#
# Epoch 00014: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_14.h5
# Epoch 15/70
# 100/100 [==============================] - 360s 4s/step - loss: 2.1959 - regression_loss: 1.6391 - classification_loss: 0.5568
#
# Epoch 00015: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_15.h5
# Epoch 16/70
# 100/100 [==============================] - 355s 4s/step - loss: 2.1658 - regression_loss: 1.6197 - classification_loss: 0.5461
#
# Epoch 00016: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_16.h5
# Epoch 17/70
# 100/100 [==============================] - 357s 4s/step - loss: 2.1191 - regression_loss: 1.5828 - classification_loss: 0.5363
#
# Epoch 00017: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_17.h5
# Epoch 18/70
# 100/100 [==============================] - 349s 3s/step - loss: 2.1086 - regression_loss: 1.5829 - classification_loss: 0.5257
#
# Epoch 00018: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_18.h5
# Epoch 19/70
# 100/100 [==============================] - 364s 4s/step - loss: 2.0591 - regression_loss: 1.5589 - classification_loss: 0.5002
#
# Epoch 00019: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_19.h5
# Epoch 20/70
# 100/100 [==============================] - 358s 4s/step - loss: 2.0240 - regression_loss: 1.5292 - classification_loss: 0.4948
#
# Epoch 00020: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_20.h5
# Epoch 21/70
# 100/100 [==============================] - 365s 4s/step - loss: 1.9923 - regression_loss: 1.5150 - classification_loss: 0.4773
#
# Epoch 00021: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_21.h5
# Epoch 22/70
# 100/100 [==============================] - 357s 4s/step - loss: 1.9434 - regression_loss: 1.4757 - classification_loss: 0.4678
#
# Epoch 00022: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_22.h5
# Epoch 23/70
# 100/100 [==============================] - 354s 4s/step - loss: 1.9294 - regression_loss: 1.4653 - classification_loss: 0.4642
#
# Epoch 00023: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_23.h5
# Epoch 24/70
# 100/100 [==============================] - 350s 4s/step - loss: 1.9112 - regression_loss: 1.4544 - classification_loss: 0.4568
#
# Epoch 00024: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_24.h5
# Epoch 25/70
# 100/100 [==============================] - 354s 4s/step - loss: 1.8879 - regression_loss: 1.4283 - classification_loss: 0.4595
#
# Epoch 00025: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_25.h5
# Epoch 26/70
# 100/100 [==============================] - 348s 3s/step - loss: 1.8470 - regression_loss: 1.4051 - classification_loss: 0.4419
#
# Epoch 00026: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_26.h5
# Epoch 27/70
# 100/100 [==============================] - 349s 3s/step - loss: 1.8089 - regression_loss: 1.3797 - classification_loss: 0.4292
#
# Epoch 00027: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_27.h5
# Epoch 28/70
# 100/100 [==============================] - 346s 3s/step - loss: 1.7867 - regression_loss: 1.3618 - classification_loss: 0.4249
#
# Epoch 00028: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_28.h5
# Epoch 29/70
# 100/100 [==============================] - 356s 4s/step - loss: 1.7471 - regression_loss: 1.3297 - classification_loss: 0.4174
#
# Epoch 00029: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_29.h5
# Epoch 30/70
# 100/100 [==============================] - 349s 3s/step - loss: 1.7626 - regression_loss: 1.3379 - classification_loss: 0.4247
#
# Epoch 00030: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_30.h5
# Epoch 31/70
# 100/100 [==============================] - 357s 4s/step - loss: 1.7317 - regression_loss: 1.3227 - classification_loss: 0.4090
#
# Epoch 00031: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_31.h5
# Epoch 32/70
# 100/100 [==============================] - 354s 4s/step - loss: 1.7046 - regression_loss: 1.3039 - classification_loss: 0.4007
#
# Epoch 00032: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_32.h5
# Epoch 33/70
# 100/100 [==============================] - 351s 4s/step - loss: 1.6731 - regression_loss: 1.2782 - classification_loss: 0.3949
#
# Epoch 00033: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_33.h5
# Epoch 34/70
# 100/100 [==============================] - 343s 3s/step - loss: 1.6744 - regression_loss: 1.2760 - classification_loss: 0.3984
#
# Epoch 00034: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_34.h5
# Epoch 35/70
# 100/100 [==============================] - 349s 3s/step - loss: 1.6619 - regression_loss: 1.2717 - classification_loss: 0.3903
#
# Epoch 00035: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_35.h5
# Epoch 36/70
# 100/100 [==============================] - 343s 3s/step - loss: 1.6623 - regression_loss: 1.2675 - classification_loss: 0.3947
#
# Epoch 00036: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_36.h5
# Epoch 37/70
# 100/100 [==============================] - 348s 3s/step - loss: 1.6376 - regression_loss: 1.2516 - classification_loss: 0.3859
#
# Epoch 00037: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_37.h5
# Epoch 38/70
# 100/100 [==============================] - 341s 3s/step - loss: 1.6416 - regression_loss: 1.2557 - classification_loss: 0.3859
#
# Epoch 00038: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_38.h5
# Epoch 39/70
# 100/100 [==============================] - 353s 4s/step - loss: 1.5925 - regression_loss: 1.2163 - classification_loss: 0.3762
#
# Epoch 00039: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_39.h5
# Epoch 40/70
# 100/100 [==============================] - 358s 4s/step - loss: 1.5986 - regression_loss: 1.2244 - classification_loss: 0.3742
#
# Epoch 00040: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_40.h5
# Epoch 41/70
# 100/100 [==============================] - 355s 4s/step - loss: 1.5803 - regression_loss: 1.2071 - classification_loss: 0.3732
#
# Epoch 00041: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_41.h5
# Epoch 42/70
# 100/100 [==============================] - 352s 4s/step - loss: 1.5764 - regression_loss: 1.2073 - classification_loss: 0.3690
#
# Epoch 00042: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_42.h5
# Epoch 43/70
# 100/100 [==============================] - 350s 3s/step - loss: 1.5580 - regression_loss: 1.1965 - classification_loss: 0.3615
#
# Epoch 00043: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_43.h5
# Epoch 44/70
# 100/100 [==============================] - 347s 3s/step - loss: 1.5558 - regression_loss: 1.1859 - classification_loss: 0.3699
#
# Epoch 00044: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_44.h5
# Epoch 45/70
# 100/100 [==============================] - 359s 4s/step - loss: 1.5326 - regression_loss: 1.1767 - classification_loss: 0.3558
#
# Epoch 00045: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_45.h5
# Epoch 46/70
# 100/100 [==============================] - 358s 4s/step - loss: 1.5388 - regression_loss: 1.1818 - classification_loss: 0.3570
#
# Epoch 00046: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_46.h5
# Epoch 47/70
# 100/100 [==============================] - 355s 4s/step - loss: 1.5204 - regression_loss: 1.1643 - classification_loss: 0.3562
#
# Epoch 00047: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_47.h5
# Epoch 48/70
# 100/100 [==============================] - 351s 4s/step - loss: 1.5104 - regression_loss: 1.1596 - classification_loss: 0.3508
#
# Epoch 00048: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_48.h5
# Epoch 49/70
# 100/100 [==============================] - 354s 4s/step - loss: 1.5044 - regression_loss: 1.1511 - classification_loss: 0.3533
#
# Epoch 00049: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_49.h5
# Epoch 50/70
# 100/100 [==============================] - 347s 3s/step - loss: 1.4914 - regression_loss: 1.1512 - classification_loss: 0.3402
#
# Epoch 00050: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_50.h5
# Epoch 51/70
# 100/100 [==============================] - 347s 3s/step - loss: 1.4776 - regression_loss: 1.1360 - classification_loss: 0.3417
#
# Epoch 00051: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_51.h5
# Epoch 52/70
# 100/100 [==============================] - 345s 3s/step - loss: 1.4639 - regression_loss: 1.1232 - classification_loss: 0.3406
#
# Epoch 00052: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_52.h5
# Epoch 53/70
# 100/100 [==============================] - 352s 4s/step - loss: 1.4796 - regression_loss: 1.1320 - classification_loss: 0.3476
#
# Epoch 00053: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_53.h5
# Epoch 54/70
# 100/100 [==============================] - 347s 3s/step - loss: 1.4601 - regression_loss: 1.1239 - classification_loss: 0.3361
#
# Epoch 00054: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_54.h5
# Epoch 55/70
# 100/100 [==============================] - 353s 4s/step - loss: 1.4570 - regression_loss: 1.1200 - classification_loss: 0.3370
#
# Epoch 00055: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_55.h5
# Epoch 56/70
# 100/100 [==============================] - 348s 3s/step - loss: 1.4473 - regression_loss: 1.1122 - classification_loss: 0.3351
#
# Epoch 00056: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_56.h5
# Epoch 57/70
# 100/100 [==============================] - 353s 4s/step - loss: 1.4344 - regression_loss: 1.1020 - classification_loss: 0.3323
#
# Epoch 00057: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_57.h5
# Epoch 58/70
# 100/100 [==============================] - 352s 4s/step - loss: 1.4190 - regression_loss: 1.0944 - classification_loss: 0.3246
#
# Epoch 00058: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_58.h5
# Epoch 59/70
# 100/100 [==============================] - 352s 4s/step - loss: 1.4234 - regression_loss: 1.0952 - classification_loss: 0.3282
#
# Epoch 00059: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_59.h5
# Epoch 60/70
# 100/100 [==============================] - 352s 4s/step - loss: 1.4162 - regression_loss: 1.0918 - classification_loss: 0.3245
#
# Epoch 00060: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_60.h5
# Epoch 61/70
# 100/100 [==============================] - 355s 4s/step - loss: 1.4111 - regression_loss: 1.0884 - classification_loss: 0.3227
#
# Epoch 00061: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_61.h5
# Epoch 62/70
# 100/100 [==============================] - 356s 4s/step - loss: 1.4049 - regression_loss: 1.0757 - classification_loss: 0.3293
#
# Epoch 00062: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv_62.h5
# Epoch 63/70
# 100/100 [==============================] - 358s 4s/step - loss: 1.3976 - regression_loss: 1.0787 - classification_loss: 0.3189
#
# Epoch 00063: saving model to /content/gdrive/My Drive/ACV2/retinaa/vgg16_csv
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Running network: N/A% (0 of 747) |        | Elapsed Time: 0:00:00 ETA:  --:--:--2020-05-15 15:41:37.015692: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-05-15 15:41:38.357075: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# Running network: 100% (747 of 747) |######| Elapsed Time: 0:01:56 Time:  0:01:56
# Parsing annotations: 100% (747 of 747) |##| Elapsed Time: 0:00:00 Time:  0:00:00
# 3678 instances of class car with average precision: 0.8276
# 446 instances of class truck with average precision: 0.3610
# 874 instances of class van with average precision: 0.5500
# 222 instances of class longvehicle with average precision: 0.2334
# 366 instances of class bus with average precision: 0.5706
# 161 instances of class airliner with average precision: 0.6081
# 25 instances of class propeller with average precision: 0.0326
# 49 instances of class trainer with average precision: 0.5270
# 103 instances of class chartered with average precision: 0.3725
# 8 instances of class fighter with average precision: 0.0044
# 85 instances of class other with average precision: 0.0102
# 83 instances of class stairtruck with average precision: 0.0593
# 55 instances of class pushback with average precision: 0.0116
# 9 instances of class helicopter with average precision: 0.0244
# 1820 instances of class boat with average precision: 0.9044
# Inference time for 747 images: 0.1090
# mAP using the weighted average of precisions among classes: 0.7217
# mAP: 0.3398

# %% [markdown]
# **Creaat the Class Mapping**

# %%
class_mapping = ['Car', 'Truck', 'Van', 'LongVehicle', 'Bus', 
                'Airliner', 'Propeller Aircraft', 'Trainer Aircraft', 'Chartered Aircraft',
                'Fighter Aircraft', 'Others', 'Stair Truck', 'Pushback Truck',
                'Helicopter', 'Boat']
class_mapping = dict(enumerate(class_mapping))

# %% [markdown]
# **Predict the Model on Image**

# %%
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
labels_to_names=class_mapping
model_path = os.path.join('m_i.h5')
model_ = models.load_model(model_path, backbone_name='resnet50')
# load image
image = read_image_bgr('/content/keras-retinanet/Dataset/test/images/0035.jpg')

# copy to draw on
draw = image.copy()
draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
image = preprocess_image(image)
image, scale = resize_image(image)

# process image
start = time.time()
boxes, scores, labels = model_.predict_on_batch(np.expand_dims(image, axis=0))
print("processing time: ", time.time() - start)

# correct for image scale
boxes /= scale

# visualize detections
for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
    if score < 0.5:
        break
        
    color = label_color(label)
    
    b = box.astype(int)
    draw_box(draw, b, color=color)
    
    caption = "{} {:.3f}".format(labels_to_names[label], score)
    draw_caption(draw, b, caption)
    
plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(draw)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[